# %% [markdown]
# Same notebook as before but now working with the self reported diseases

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
ukbb_dis = pd.read_excel('Diseases Excels/19406_20002.xlsx')

# %% [markdown]
# Filter only the patients with the diseases selected:
#
# Hypertension - > 1065
#
# Angina -> 1074
#
# Atrial Fibrilliation - > 1471
#
# Heart Valve -> 1078
#
# Heart Arrhytmia -> 1077

# %%
### Patients with diseases

ukbb_dis.head(10)
# Out:
#      f.eid  f.20002.1.0  f.20002.2.0  f.20002.0.0  f.20002.2.1  f.20002.0.1  \
# 0  1000195          NaN       1065.0          NaN       1220.0          NaN
# 1  1000231          NaN       1548.0       1465.0       1599.0       1294.0
# 2  1000384          NaN       1597.0          NaN          NaN          NaN
# 3  1000511          NaN          NaN          NaN          NaN          NaN
# 4  1001553          NaN       1387.0       1387.0       1473.0       1374.0
# 5  1001596          NaN       1111.0          NaN       1402.0          NaN
# 6  1002136          NaN          NaN          NaN          NaN          NaN
# 7  1002320          NaN       1466.0       1466.0       1534.0          NaN
# 8  1002513       1471.0       1471.0          NaN          NaN          NaN
# 9  1002879          NaN       1138.0       1154.0          NaN          NaN
#
#    f.20002.1.1  f.20002.2.2  f.20002.1.2  f.20002.0.2  ...  f.20002.0.30  \
# ...

# %%
ukbb_dis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19406 entries, 0 to 19405
# Columns: 103 entries, f.eid to f.20002.1.33
# dtypes: float64(102), int64(1)
# memory usage: 15.2 MB

# %%
ukbb_dis.isin(['1065.0']).sum().sum()
# Out:
# 8997

# %%
HYP = list()

# %%
for col in ukbb_dis.columns:
    HYP.append(list(ukbb_dis[ukbb_dis[col]==1065.0]['f.eid']))

# %%
def flatten_list(list1):
    flat_list = []
    for sublist in list1:
        for item in sublist:
            flat_list.append(item)
            
    return flat_list

# %%
HYP = flatten_list(HYP)

# %%
len(HYP)
# Out:
# 8997

# %%
ANG = list()
for col in ukbb_dis.columns:
    ANG.append(list(ukbb_dis[ukbb_dis[col]==1074.0]['f.eid']))

ANG = flatten_list(ANG)

# %%
len(ANG)
# Out:
# 829

# %%
ATFB = list()
for col in ukbb_dis.columns:
    ATFB.append(list(ukbb_dis[ukbb_dis[col]==1471.0]['f.eid']))

ATFB = flatten_list(ATFB)

# %%
len(ATFB)
# Out:
# 354

# %%
HV = list()
for col in ukbb_dis.columns:
    HV.append(list(ukbb_dis[ukbb_dis[col]==1078.0]['f.eid']))

HV = flatten_list(HV)

# %%
len(HV)
# Out:
# 191

# %%
HAR = list()
for col in ukbb_dis.columns:
    HAR.append(list(ukbb_dis[ukbb_dis[col]==1077.0]['f.eid']))

HAR = flatten_list(HAR)

# %%
len(HAR)
# Out:
# 129

# %%
radiomics = pd.read_csv('Radiomics Experiment/Radiomics_UKBB_only(1).csv')

# %%
radiomics.shape
# Out:
# (19406, 679)

# %%
radiomics.head()
# Out:
#      f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 0  1000195  127364.63600        15975.77156                        0.126230
# 1  1000231  113179.63330        14324.47422                        0.127436
# 2  1000384  172890.17310        19808.67185                        0.115331
# 3  1000511   96791.78314        12787.16759                        0.133135
# 4  1001553  143018.20370        16823.49655                        0.118307
#
#    Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 0          0.763054                   Deprecated        Deprecated
# 1          0.786314                   Deprecated        Deprecated
# 2          0.754343                   Deprecated        Deprecated
# 3          0.793165                   Deprecated        Deprecated
# 4          0.783138                   Deprecated        Deprecated
#
#   Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
healthy_ids = pd.read_excel('Diseases Excels/Ids_healthy_subjects.xlsx', header=None)

# %%
list(healthy_ids[0])
# Out:
# [1003177,
#  1023154,
#  1027278,
#  1043788,
#  1043973,
#  1052312,
#  1060224,
#  1060793,
#  1063523,
#  1074044,
#  1084667,
#  1090805,
#  1095416,
#  1101325,
#  1106075,
#  1123251,
#  1128392,
#  1135418,
#  1135902,
#  1137386,
#  1144034,
#  1145973,
#  1153555,
#  1156718,
#  1158299,
#  1160907,
#  1168100,
#  1189718,
#  1196200,
#  1198540,
#  1203290,
#  1204256,
#  1229986,
#  1240815,
#  1251252,
#  1268245,
#  1269544,
#  1273702,
#  1282848,
#  1291991,
#  1300094,
#  1301497,
#  1314663,
#  1317759,
#  1327618,
#  1349141,
#  1351156,
#  1354670,
#  1364364,
#  1368479,
#  1371495,
#  1385346,
#  1389581,
#  1391595,
#  1399699,
#  1400557,
#  1413621,
#  1419663,
#  1421694,
#  1427678,
#  1429487,
#  1441230,
#  1442733,
#  1452200,
#  1454551,
#  1456884,
#  1465277,
#  1483920,
#  1487421,
#  1489525,
#  1499732,
#  1532778,
#  1538140,
#  1558353,
#  1559971,
#  1570349,
#  1577234,
#  1577577,
#  1581609,
#  1585318,
#  1600332,
#  1608004,
#  1616987,
# ...

# %%
radiomics['f.eid'].isin(healthy_ids[0]).sum().sum()
# Out:
# 780

# %%
healthy_rad = radiomics[radiomics['f.eid'].isin(healthy_ids[0])]

# %%
healthy_rad['class'] = 'HEALTHY'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
healthy_rad.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 11   1003177   167950.4539        20927.86259                        0.125441
# 84   1023154   109174.4703        14942.90187                        0.138011
# 97   1027278   136651.9821        16471.76602                        0.121364
# 160  1043788   154633.2177        17678.57129                        0.114961
# 164  1043973   160874.6189        20627.93572                        0.129261
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 11           0.700296                   Deprecated        Deprecated
# 84           0.735185                   Deprecated        Deprecated
# 97           0.775374                   Deprecated        Deprecated
# 160          0.785179                   Deprecated        Deprecated
# 164          0.689744                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
healthy_rad.tail()
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 19297  6000090   155901.5238        17405.16606
# 19340  6009243   151963.0995        18075.53927
# 19344  6010117   158271.2743        17891.69036
# 19348  6010487   109808.6235        13972.21103
# 19377  6019216   148437.7343        18054.40564
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 19297                        0.112246          0.801945
# 19340                        0.119707          0.758648
# 19344                        0.113698          0.787829
# 19348                        0.128149          0.789926
# 19377                        0.122460          0.747528
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 19297                   Deprecated        Deprecated         Deprecated
# 19340                   Deprecated        Deprecated         Deprecated
# 19344                   Deprecated        Deprecated         Deprecated
# ...

# %%
HYP_rad = radiomics[radiomics['f.eid'].isin(HYP)]

# %%
radiomics['f.eid'].isin(HYP).sum()
# Out:
# 5342

# %%
HYP_rad.shape
# Out:
# (5342, 679)

# %%
HYP_rad.head()
# Out:
#       f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 0   1000195   127364.6360        15975.77156                        0.126230
# 12  1003323   149993.9070        17209.24043                        0.115378
# 13  1003439   136409.6791        15808.84302                        0.116614
# 16  1004600   122124.5451        15678.68585                        0.129333
# 22  1005521   128799.8245        16434.84767                        0.128516
#
#     Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 0           0.763054                   Deprecated        Deprecated
# 12          0.790342                   Deprecated        Deprecated
# 13          0.807266                   Deprecated        Deprecated
# 16          0.755513                   Deprecated        Deprecated
# 22          0.746892                   Deprecated        Deprecated
#
#    Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
HYP = list(HYP_rad['f.eid'])

# %%
len(HYP)
# Out:
# 5342

# %%
ANG_rad = radiomics[radiomics['f.eid'].isin(ANG)]

# %%
list2 = list(ANG_rad['f.eid'])

# %%
len(list2)
# Out:
# 526

# %%
HYP_rad['class'] = 'HYP'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
HYP_rad.shape
# Out:
# (5342, 680)

# %%
ANG_rad['class'] = 'ANG'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ANG_rad.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 32   1008556   172956.9035        18863.32813                        0.109658
# 83   1022143   150461.1777        17224.28795                        0.115158
# 115  1033167   205265.3600        22463.36859                        0.110023
# 172  1045895   108598.2582        15502.69098                        0.144069
# 204  1056657   119654.6855        15261.72882                        0.128376
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 32           0.792960                   Deprecated        Deprecated
# 83           0.791118                   Deprecated        Deprecated
# 115          0.746454                   Deprecated        Deprecated
# 172          0.705723                   Deprecated        Deprecated
# 204          0.766114                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
ATFB_rad = radiomics[radiomics['f.eid'].isin(ATFB)]

# %%
ATFB_rad['class']= 'ATFB'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
HV_rad = radiomics[radiomics['f.eid'].isin(HV)]

# %%
HV_rad['class']= 'HV'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
HV_rad.shape
# Out:
# (170, 680)

# %%
ATFB_rad.shape
# Out:
# (268, 680)

# %%
HAR_rad = radiomics[radiomics['f.eid'].isin(HAR)]
HAR_rad['class']= 'HAR'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
HAR_rad.shape
# Out:
# (124, 680)

# %%
first_exp = pd.concat([HYP_rad, healthy_rad], axis=0, join='inner')

# %%
first_exp.shape
# Out:
# (6122, 680)

# %%
first_exp.drop_duplicates(subset='f.eid', keep='last', inplace=True)

# %%
first_exp['class'].value_counts()
# Out:
# HYP        5335
# HEALTHY     780
# Name: class, dtype: int64

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.index.droplevel(0)
    return df_

# %%
#HYP_rad = stratified_sample_df(first_exp, 'class', 150)

# %%
HYP_rad = stratified_sample_df(first_exp, 'class', 780)

# %%
HYP_rad['class'].value_counts()
# Out:
# HEALTHY    780
# HYP        780
# Name: class, dtype: int64

# %%
#HYP_rad.to_csv('Radiomics Experiment/HYPERTHENSION/Hyperthension_rad.csv')

# %%
HYP_rad.to_csv(r'C:\Users\alex1\Documents\Fundamentals_of_Data_Science\TFM\UKBB Dataset\1. Radiomics\Larger Dataset\HYPERTHENSION\Hyperthension_rad.csv')

# %% [markdown]
# - Experiments with binary classification --- All diseases vs Healthy
#
# 1)

# %%
healthy_rad_samp1 = healthy_rad.sample(n=len(ANG_rad))

# %%
second_exp = pd.concat([ANG_rad, healthy_rad_samp1], axis=0)

# %%
second_exp['class'].value_counts()
# Out:
# ANG        526
# healthy    526
# Name: class, dtype: int64

# %%
second_exp.to_csv('Radiomics Experiment/20002/ANG_healthy.csv')

# %% [markdown]
# 2)

# %%
healthy_rad_samp2 = healthy_rad.sample(n=len(ATFB_rad))

# %%
third = pd.concat([ATFB_rad, healthy_rad_samp2], axis = 0)

# %%
third['class'].value_counts()
# Out:
# ATFB       268
# healthy    268
# Name: class, dtype: int64

# %%
third.to_csv('Radiomics Experiment/20002/ATFB_healthy.csv')

# %% [markdown]
# 3)

# %%
healthy_rad_samp3 = healthy_rad.sample(n=len(HV_rad))

# %%
fourth = pd.concat([HV_rad, healthy_rad_samp3], axis=0)

# %%
fourth['class'].value_counts()
# Out:
# healthy    170
# HV         170
# Name: class, dtype: int64

# %%
fourth.to_csv('Radiomics Experiment/20002/HV_healthy.csv')

# %% [markdown]
# 4)

# %%
healthy_rad_samp4 = healthy_rad.sample(n=len(HAR_rad))

# %%
fith = pd.concat([HAR_rad, healthy_rad_samp4], axis=0)

# %%
fith['class'].value_counts()
# Out:
# HAR        124
# healthy    124
# Name: class, dtype: int64

# %%
fith.to_csv('Radiomics Experiment/20002/HAR_healthy.csv')

# %%
# third_exp.shape

# %% [markdown]
# 5) All togthere
#
# This shouldn't work much since there are repeated patients

# %%
#all_data = pd.concat([HYP_rad, ANG_rad,HV_rad, ATFB_rad, HAR_rad, healthy_rad], axis=0)

# %%
all_data = pd.concat([HYP_rad, ANG_rad, ATFB_rad, healthy_rad], axis=0)

# %%
all_data['class'].value_counts()
# Out:
# HYP        5342
# healthy     780
# ANG         526
# ATFB        268
# Name: class, dtype: int64

# %%
all_data.tail()
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 19297  6000090   155901.5238        17405.16606
# 19340  6009243   151963.0995        18075.53927
# 19344  6010117   158271.2743        17891.69036
# 19348  6010487   109808.6235        13972.21103
# 19377  6019216   148437.7343        18054.40564
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 19297                        0.112246          0.801945
# 19340                        0.119707          0.758648
# 19344                        0.113698          0.787829
# 19348                        0.128149          0.789926
# 19377                        0.122460          0.747528
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 19297                   Deprecated        Deprecated         Deprecated
# 19340                   Deprecated        Deprecated         Deprecated
# 19344                   Deprecated        Deprecated         Deprecated
# ...

# %%
#sixth_exp.to_csv('Radiomics Experiment/sixth_exp.csv')

# %% [markdown]
# 7) Joining together both anginas
#
# Still, repeated patients

# %%
# angina_rad = pd.concat([I209_rad, I200_rad], axis=0)
# angina_rad['class']= 'angina'

# %%
# seventh_exp = pd.concat([I251_rad, I48_rad, angina_rad, healthy_rad], axis = 0)
# seventh_exp['class'].value_counts()

# %%
#seventh_exp.to_csv('Radiomics Experiment/seventh_exp.csv')

# %% [markdown]
# 8) Stratification
# random Sampling, also repeated patients

# %%
# I251_rad_samp = I251_rad.sample(n=120)
# I48_rad_samp = I48_rad.sample(n=120)
# I209_rad_samp = I209_rad.sample(n=120)
# I200_rad_samp = I200_rad.sample(n=120)
# # angina_rad_samp = angina_rad.sample(n=120)
# healthy_rad_samp = healthy_rad.sample(n=120)

# %%
# strat_df = pd.concat([I251_rad_samp, I48_rad_samp,angina_rad_samp, healthy_rad_samp], axis=0)

# %%
# strat_df['class'].value_counts()

# %%
#strat_df.to_csv('Radiomics Experiment/strat_df.csv')

# %% [markdown]
# 8) Angina dataset
#
# This should be the third experiment

# %%
# healthy_rad_samp4 = healthy_rad.sample(n=len(angina_rad))

# %%
# angina_df = pd.concat([angina_rad, healthy_rad_samp4], axis=0)

# %%
# angina_df.to_csv('Radiomics Experiment/angina_df.csv')

# %% [markdown]
# 9) Avoiding duplicates

# %%
all_data_ndup = all_data.drop_duplicates(subset='f.eid', keep=False)

# %%
all_data_ndup['class'].value_counts()
# Out:
# HYP        4907
# healthy     773
# ANG         203
# ATFB        137
# Name: class, dtype: int64

# %%
#all_data_ndup.to_csv('Radiomics Experiment/20002/all_data_ndup.csv')

# %% [markdown]
# 10) Strat w/ duplicates

# %%
# tenth_exp = seventh_exp.drop_duplicates(subset='f.eid', keep=False)

# %%
# tenth_exp['class'].value_counts()

# %%
# tenth_exp.to_csv('Radiomics Experiment/tenth_exp.csv')

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.index.droplevel(0)
    return df_

# %%
tenth_exp_ = stratified_sample_df(all_data_ndup, 'class', 130)

# %%
tenth_exp_['class'].value_counts()
# Out:
# HYP        130
# ATFB       130
# healthy    130
# ANG        130
# Name: class, dtype: int64

# %%
tenth_exp_.to_csv('Radiomics Experiment/20002/all_data_strat.csv')
