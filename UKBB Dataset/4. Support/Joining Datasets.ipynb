# %%
import pandas as pd

# %% [markdown]
# Angina Dataset

# %%
angina1 = pd.read_csv('Radiomics Experiment/angina_df.csv', index_col=0)

# %%
angina1.head()
# Out:
#         f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 83    1022143   150461.1777        17224.28795
# 367   1097355   145012.5703        17191.90636
# 671   1172652   166481.8670        19951.80457
# 839   1209413   180466.6108        23980.60487
# 1051  1268384   106737.9733        14354.74748
#
#       SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 83                          0.115158          0.791118
# 367                         0.119333          0.773040
# 671                         0.120566          0.730590
# 839                         0.133811          0.641016
# 1051                        0.135537          0.754133
#
#      SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 83                     Deprecated        Deprecated         Deprecated
# 367                    Deprecated        Deprecated         Deprecated
# 671                    Deprecated        Deprecated         Deprecated
# ...

# %%
angina2 = pd.read_csv('Radiomics Experiment/20002/ANG_healthy.csv', index_col=0)

# %%
angina2.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 32   1008556   172956.9035        18863.32813                        0.109658
# 83   1022143   150461.1777        17224.28795                        0.115158
# 115  1033167   205265.3600        22463.36859                        0.110023
# 172  1045895   108598.2582        15502.69098                        0.144069
# 204  1056657   119654.6855        15261.72882                        0.128376
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 32           0.792960                   Deprecated        Deprecated
# 83           0.791118                   Deprecated        Deprecated
# 115          0.746454                   Deprecated        Deprecated
# 172          0.705723                   Deprecated        Deprecated
# 204          0.766114                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
angina_tot = pd.concat([angina1, angina2], axis=0)

# %%
angina_tot['class'].value_counts()
# Out:
# healthy    526
# ANG        526
# ANGINA     292
# HEALTHY    292
# Name: class, dtype: int64

# %%
angina_tot.replace(to_replace='ANG', value='ANGINA', inplace=True)
angina_tot.replace(to_replace='healthy', value='HEALTHY', inplace=True)

# %%
angina_tot['class'].value_counts()
# Out:
# ANGINA     818
# HEALTHY    818
# Name: class, dtype: int64

# %%
angina_tot = angina_tot.drop_duplicates(subset='f.eid', keep=False)

# %%
angina_tot['class'].value_counts()
# Out:
# ANGINA     519
# HEALTHY    416
# Name: class, dtype: int64

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.index.droplevel(0)
    return df_

# %%
#angina_tot = stratified_sample_df(angina_tot, 'class', 400)

# %%
#angina_tot['class'].value_counts()
# Out:
# ANGINA     400
# HEALTHY    400
# Name: class, dtype: int64

# %%
#angina_tot.to_csv(r'C:\Users\alex1\Documents\Fundamentals_of_Data_Science\TFM\UKBB Dataset\1. Radiomics\Larger Dataset\ANGINAangina_tot.csv')

# %% [markdown]
# Atrial Fibrilliation

# %%
atfb1 = pd.read_csv('Radiomics Experiment/fourth_exp.csv', index_col=0)

# %%
atfb2 = pd.read_csv('Radiomics Experiment/20002/ATFB_healthy.csv', index_col=0)

# %%
atfb_tot = pd.concat([atfb1, atfb2], axis=0)

# %%
atfb_tot['class'].value_counts()
# Out:
# healthy    268
# ATFB       268
# HEALTHY    241
# ATRFB      241
# Name: class, dtype: int64

# %%
atfb_tot.replace(to_replace='ATRFB', value='ATFB', inplace=True)
atfb_tot.replace(to_replace='healthy', value='HEALTHY', inplace=True)

# %%
atfb_tot['class'].value_counts()
# Out:
# HEALTHY    509
# ATFB       509
# Name: class, dtype: int64

# %%
atfb_tot = atfb_tot.drop_duplicates(subset='f.eid', keep=False)

# %%
atfb_tot['class'].value_counts()
# Out:
# HEALTHY    350
# ATFB       228
# Name: class, dtype: int64

# %%
atfb_tot = stratified_sample_df(atfb_tot, 'class', 220)

# %%
#atfb_tot = stratified_sample_df(atfb_tot, 'class', 500)

# %%
#atfb_tot.to_csv(r'C:\Users\alex1\Documents\Fundamentals_of_Data_Science\TFM\UKBB Dataset\1. Radiomics\Larger Dataset\ATRIAL FIBRILIATION\atfb_tot.csv')

# %% [markdown]
# Angina

# %%
angina_tot.shape
# Out:
# (390, 680)

# %%
angina_head =angina_tot.head()

# %%
angina_head
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 469    1123116   175827.3035        19106.72475
# 17968  5671957   131636.8422        15995.66738
# 6400   2639309   171400.0000        18917.60722
# 18966  5915353   104768.1688        14109.74841
# 18975  5916332   206060.2236        21071.05501
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 469                          0.109236          0.791610
# 17968                        0.122412          0.778514
# 6400                         0.111079          0.785432
# 18966                        0.135750          0.757676
# 18975                        0.102772          0.798005
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 469                     Deprecated        Deprecated         Deprecated
# 17968                   Deprecated        Deprecated         Deprecated
# 6400                    Deprecated        Deprecated         Deprecated
# ...

# %%
angina_head.sort_values(by='f.eid', inplace=True)
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
angina_head['f.eid']
# Out:
# 469      1123116
# 17968    5671957
# 6400     2639309
# 18966    5915353
# 18975    5916332
# Name: f.eid, dtype: int64

# %%
list1 = [5916332,5915353, 2639309, 1123116,5671957]

# %%
angina_sort2 = angina_head.sort_values(by='f.eid')

# %%
angina_sort2['class2']=2

# %%
angina_sort2
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 469    1123116   175827.3035        19106.72475
# 6400   2639309   171400.0000        18917.60722
# 17968  5671957   131636.8422        15995.66738
# 18966  5915353   104768.1688        14109.74841
# 18975  5916332   206060.2236        21071.05501
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 469                          0.109236          0.791610
# 6400                         0.111079          0.785432
# 17968                        0.122412          0.778514
# 18966                        0.135750          0.757676
# 18975                        0.102772          0.798005
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 469                     Deprecated        Deprecated         Deprecated
# 6400                    Deprecated        Deprecated         Deprecated
# 17968                   Deprecated        Deprecated         Deprecated
# ...

# %%
angina_head.join(angina_sort2, how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-bc65e1c2f759> in <module>
# ----> 1 angina_head.join(angina_sort2, how='left')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...

# %%
angina_trial.shape
# Out:
# (5, 1361)

# %%
angina_tot.sort_values(by='f.eid')
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 32     1008556   172956.9035        18863.32813
# 97     1027278   136651.9821        16471.76602
# 191    1052312   140047.6109        16370.91664
# 204    1056657   119654.6855        15261.72882
# 242    1065124   200080.1301        22337.30999
# ...        ...           ...                ...
# 19172  5963605   123480.5057        15253.05692
# 19256  5984672   177696.3633        20440.66206
# 19310  6002379   164373.0823        19236.19841
# 19348  6010487   109808.6235        13972.21103
# 19387  6021959   137629.5888        16568.96545
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 32                           0.109658          0.792960
# 97                           0.121364          0.775374
# 191                          0.117619          0.793370
# 204                          0.128376          0.766114
# 242                          0.112263          0.737874
# ...
