# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
ukbb_dis = pd.read_excel('Diseases Excels/19406_41202.xlsx')

# %% [markdown]
# Filter only the patients with the diseases selected:
#
# I25.1 Atherosclerotic heart disease -> code I251
#
# I48 Atrial fibrillation and flutter - code I48
#
# I20.9 Angina pectoris, unspecified -> code I209
#
# I20.0 Unstable angina  -> I200

# %%
### Patients with diseases

ukbb_dis.head()
# Out:
#      f.eid f.41202.0.0 f.41202.0.1 f.41202.0.2 f.41202.0.3 f.41202.0.4  \
# 0  1000195        J039         NaN         NaN         NaN         NaN
# 1  1000231        M201        N851         NaN         NaN         NaN
# 2  1000384        C442        G560         NaN         NaN         NaN
# 3  1000511         NaN         NaN         NaN         NaN         NaN
# 4  1001553         NaN         NaN         NaN         NaN         NaN
#
#   f.41202.0.5 f.41202.0.6 f.41202.0.7 f.41202.0.8  ... f.41202.0.56  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2         NaN         NaN         NaN         NaN  ...          NaN
# 3         NaN         NaN         NaN         NaN  ...          NaN
# 4         NaN         NaN         NaN         NaN  ...          NaN
#
#   f.41202.0.57 f.41202.0.58 f.41202.0.59 f.41202.0.60 f.41202.0.61  \
# ...

# %%
ukbb_dis.isin(['I251']).sum()
# Out:
# f.eid             0
# f.41202.0.0     180
# f.41202.0.1     156
# f.41202.0.2      95
# f.41202.0.3      43
#                ...
# f.41202.0.61      0
# f.41202.0.62      0
# f.41202.0.63      0
# f.41202.0.64      0
# f.41202.0.65      0
# Length: 67, dtype: int64

# %%
I251 = list()

# %%
for col in ukbb_dis.columns:
    I251.append(list(ukbb_dis[ukbb_dis[col]=='I251']['f.eid']))
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
def flatten_list(list1):
    flat_list = []
    for sublist in list1:
        for item in sublist:
            flat_list.append(item)
            
    return flat_list

# %%
I251 = flatten_list(I251)

# %%
len(I251)
# Out:
# 511

# %%
I48 = list()
for col in ukbb_dis.columns:
    I48.append(list(ukbb_dis[ukbb_dis[col]=='I48']['f.eid']))

I48 = flatten_list(I48)

# %%
len(I48)
# Out:
# 241

# %%
I209 = list()
for col in ukbb_dis.columns:
    I209.append(list(ukbb_dis[ukbb_dis[col]=='I209']['f.eid']))

I209 = flatten_list(I209)

# %%
len(I209)
# Out:
# 171

# %%
I200 = list()
for col in ukbb_dis.columns:
    I200.append(list(ukbb_dis[ukbb_dis[col]=='I200']['f.eid']))

I200 = flatten_list(I200)

# %%
len(I200)
# Out:
# 121

# %%
radiomics = pd.read_csv('Radiomics Experiment/Radiomics_UKBB_only(1).csv')

# %%
radiomics.head()
# Out:
#      f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 0  1000195  127364.63600        15975.77156                        0.126230
# 1  1000231  113179.63330        14324.47422                        0.127436
# 2  1000384  172890.17310        19808.67185                        0.115331
# 3  1000511   96791.78314        12787.16759                        0.133135
# 4  1001553  143018.20370        16823.49655                        0.118307
#
#    Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 0          0.763054                   Deprecated        Deprecated
# 1          0.786314                   Deprecated        Deprecated
# 2          0.754343                   Deprecated        Deprecated
# 3          0.793165                   Deprecated        Deprecated
# 4          0.783138                   Deprecated        Deprecated
#
#   Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
healthy_ids = pd.read_excel('Diseases Excels/Ids_healthy_subjects.xlsx', header=None)

# %%
list(healthy_ids[0])
# Out:
# [1003177,
#  1023154,
#  1027278,
#  1043788,
#  1043973,
#  1052312,
#  1060224,
#  1060793,
#  1063523,
#  1074044,
#  1084667,
#  1090805,
#  1095416,
#  1101325,
#  1106075,
#  1123251,
#  1128392,
#  1135418,
#  1135902,
#  1137386,
#  1144034,
#  1145973,
#  1153555,
#  1156718,
#  1158299,
#  1160907,
#  1168100,
#  1189718,
#  1196200,
#  1198540,
#  1203290,
#  1204256,
#  1229986,
#  1240815,
#  1251252,
#  1268245,
#  1269544,
#  1273702,
#  1282848,
#  1291991,
#  1300094,
#  1301497,
#  1314663,
#  1317759,
#  1327618,
#  1349141,
#  1351156,
#  1354670,
#  1364364,
#  1368479,
#  1371495,
#  1385346,
#  1389581,
#  1391595,
#  1399699,
#  1400557,
#  1413621,
#  1419663,
#  1421694,
#  1427678,
#  1429487,
#  1441230,
#  1442733,
#  1452200,
#  1454551,
#  1456884,
#  1465277,
#  1483920,
#  1487421,
#  1489525,
#  1499732,
#  1532778,
#  1538140,
#  1558353,
#  1559971,
#  1570349,
#  1577234,
#  1577577,
#  1581609,
#  1585318,
#  1600332,
#  1608004,
#  1616987,
# ...

# %%
radiomics['f.eid'].isin(healthy_ids[0]).sum().sum()
# Out:
# 780

# %%
healthy_rad = radiomics[radiomics['f.eid'].isin(healthy_ids[0])]

# %%
healthy_rad['class'] = 'HEALTHY'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
healthy_rad.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 11   1003177   167950.4539        20927.86259                        0.125441
# 84   1023154   109174.4703        14942.90187                        0.138011
# 97   1027278   136651.9821        16471.76602                        0.121364
# 160  1043788   154633.2177        17678.57129                        0.114961
# 164  1043973   160874.6189        20627.93572                        0.129261
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 11           0.700296                   Deprecated        Deprecated
# 84           0.735185                   Deprecated        Deprecated
# 97           0.775374                   Deprecated        Deprecated
# 160          0.785179                   Deprecated        Deprecated
# 164          0.689744                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
healthy_rad.tail()
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 19297  6000090   155901.5238        17405.16606
# 19340  6009243   151963.0995        18075.53927
# 19344  6010117   158271.2743        17891.69036
# 19348  6010487   109808.6235        13972.21103
# 19377  6019216   148437.7343        18054.40564
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 19297                        0.112246          0.801945
# 19340                        0.119707          0.758648
# 19344                        0.113698          0.787829
# 19348                        0.128149          0.789926
# 19377                        0.122460          0.747528
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 19297                   Deprecated        Deprecated         Deprecated
# 19340                   Deprecated        Deprecated         Deprecated
# 19344                   Deprecated        Deprecated         Deprecated
# ...

# %%
I251_rad = radiomics[radiomics['f.eid'].isin(I251)]

# %%
I251_rad.shape
# Out:
# (511, 679)

# %%
I251_rad.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 115  1033167   205265.3600        22463.36859                        0.110023
# 204  1056657   119654.6855        15261.72882                        0.128376
# 248  1067432   170588.5269        19565.28663                        0.115419
# 334  1090331   186960.0243        20548.40000                        0.110496
# 337  1091016   205912.9464        22127.88249                        0.108028
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 115          0.746454                   Deprecated        Deprecated
# 204          0.766114                   Deprecated        Deprecated
# 248          0.757071                   Deprecated        Deprecated
# 334          0.766762                   Deprecated        Deprecated
# 337          0.759416                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
list1 = list(I251_rad['f.eid'])

# %%
len(list1)
# Out:
# 511

# %%
I48_rad = radiomics[radiomics['f.eid'].isin(I48)]

# %%
list2 = list(I48_rad['f.eid'])

# %%
len(list2)
# Out:
# 241

# %%
I251_rad['class'] = 'ATH'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
I251_rad.shape
# Out:
# (511, 680)

# %%
I48_rad['class'] = 'ATRFB'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
I48_rad.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 124  1035697   139040.8123        16726.81887                        0.121115
# 192  1052350   131848.0454        18468.38817                        0.141391
# 214  1058878   239681.9687        24330.72559                        0.101992
# 362  1096305   201281.5384        21524.30913                        0.107560
# 443  1116972   132382.9089        18106.25145                        0.138018
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 124          0.772471                   Deprecated        Deprecated
# 192          0.674102                   Deprecated        Deprecated
# 214          0.764520                   Deprecated        Deprecated
# 362          0.768669                   Deprecated        Deprecated
# 443          0.689581                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# ...

# %%
I209_rad = radiomics[radiomics['f.eid'].isin(I209)]

# %%
I209_rad['class']= 'I209'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
I200_rad = radiomics[radiomics['f.eid'].isin(I200)]

# %%
I200_rad['class']= 'I200'
# Out:
# C:\Users\alex1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
I209_rad.shape
# Out:
# (171, 680)

# %%
I200_rad.shape
# Out:
# (121, 680)

# %%
first = I251+I48

# %%
len(first)
# Out:
# 752

# %%
seen = set()
uniq = []
for x in first:
    if x not in seen:
        uniq.append(x)
        seen.add(x)

# %%
len(uniq)
# Out:
# 724

# %%
#first_exp = pd.concat([I251_rad, I48_rad], axis=0, join='inner')

# %%
#first_exp.shape

# %%
#first_exp.drop_duplicates(subset='f.eid', keep='last', inplace=True)

# %%
#first_exp['class'].value_counts()

# %%
#first_exp.to_csv('Radiomics Experiment/first_exp.csv')

# %% [markdown]
# - Experiments with binary classification --- All diseases vs Healthy
#
# 1)

# %%
healthy_rad_samp1 = healthy_rad.sample(n=len(I251))

# %%
second_exp = pd.concat([I251_rad, healthy_rad_samp1], axis=0)

# %%
second_exp['class'].value_counts()
# Out:
# HEALTHY    511
# ATH        511
# Name: class, dtype: int64

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.index.droplevel(0)
    return df_

# %%
ATH_rad = stratified_sample_df(second_exp, 'class', 500)

# %%
ATH_rad['class'].value_counts()
# Out:
# HEALTHY    500
# ATH        500
# Name: class, dtype: int64

# %%
#second_exp.to_csv('Radiomics Experiment/second_exp.csv')

# %%
ATH_rad.to_csv(r'C:\Users\alex1\Documents\Fundamentals_of_Data_Science\TFM\UKBB Dataset\1. Radiomics\Larger Dataset\ATHEROSCLEROTIC\ATH_rad.csv')

# %% [markdown]
# 2)

# %%
healthy_rad_samp2 = healthy_rad.sample(n=len(I48))

# %%
fourth_exp = pd.concat([I48_rad, healthy_rad_samp2], axis = 0)

# %%
fourth_exp['class'].value_counts()
# Out:
# HEALTHY    241
# ATRFB      241
# Name: class, dtype: int64

# %%
fourth_exp.to_csv('Radiomics Experiment/fourth_exp.csv')

# %% [markdown]
# 3)

# %%
healthy_rad_samp3 = healthy_rad.sample(n=len(I209))

# %%
third_exp = pd.concat([I209_rad, healthy_rad_samp3], axis=0)

# %%
third_exp['class'].value_counts()
# Out:
# HEALTHY    171
# I209       171
# Name: class, dtype: int64

# %% [markdown]
# third_exp.to_csv('Radiomics Experiment/thirdd_exp.csv')

# %% [markdown]
# 4)

# %%
healthy_rad_samp4 = healthy_rad.sample(n=len(I200))

# %%
fith = pd.concat([I200_rad, healthy_rad_samp4], axis=0)

# %%
fith['class'].value_counts()
# Out:
# I200       121
# HEALTHY    121
# Name: class, dtype: int64

# %% [markdown]
# fith.to_csv('Radiomics Experiment/fith_exp.csv')

# %%
third_exp.shape
# Out:
# (342, 680)

# %% [markdown]
# 5) All togthere
#
# This shouldn't work much since there are repeated patients

# %%
sixth_exp = pd.concat([I251_rad, I48_rad,I200_rad, I209_rad, healthy_rad], axis=0)

# %%
sixth_exp['class'].value_counts()
# Out:
# HEALTHY    780
# ATH        511
# ATRFB      241
# I209       171
# I200       121
# Name: class, dtype: int64

# %%
sixth_exp.tail()
# Out:
#          f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 19297  6000090   155901.5238        17405.16606
# 19340  6009243   151963.0995        18075.53927
# 19344  6010117   158271.2743        17891.69036
# 19348  6010487   109808.6235        13972.21103
# 19377  6019216   148437.7343        18054.40564
#
#        SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  \
# 19297                        0.112246          0.801945
# 19340                        0.119707          0.758648
# 19344                        0.113698          0.787829
# 19348                        0.128149          0.789926
# 19377                        0.122460          0.747528
#
#       SphericalDisproportion_LV_ED Compactness_LV_ED Compactness2_LV_ED  \
# 19297                   Deprecated        Deprecated         Deprecated
# 19340                   Deprecated        Deprecated         Deprecated
# 19344                   Deprecated        Deprecated         Deprecated
# ...

# %%
#sixth_exp.to_csv('Radiomics Experiment/sixth_exp.csv')

# %% [markdown]
# 7) Joining together both anginas
#
# Still, repeated patients

# %%
angina_rad = pd.concat([I209_rad, I200_rad], axis=0)
angina_rad['class']= 'ANGINA'

# %%
seventh_exp = pd.concat([I251_rad, I48_rad, angina_rad, healthy_rad], axis = 0)
seventh_exp['class'].value_counts()
# Out:
# healthy    780
# I251       511
# angina     292
# I48        241
# Name: class, dtype: int64

# %%
#seventh_exp.to_csv('Radiomics Experiment/seventh_exp.csv')

# %% [markdown]
# 8) Stratification
# random Sampling, also repeated patients

# %%
I251_rad_samp = I251_rad.sample(n=120)
I48_rad_samp = I48_rad.sample(n=120)
I209_rad_samp = I209_rad.sample(n=120)
I200_rad_samp = I200_rad.sample(n=120)
angina_rad_samp = angina_rad.sample(n=120)
healthy_rad_samp = healthy_rad.sample(n=120)

# %%
strat_df = pd.concat([I251_rad_samp, I48_rad_samp,angina_rad_samp, healthy_rad_samp], axis=0)

# %%
strat_df['class'].value_counts()
# Out:
# angina     120
# I48        120
# healthy    120
# I251       120
# Name: class, dtype: int64

# %%
#strat_df.to_csv('Radiomics Experiment/strat_df.csv')

# %% [markdown]
# 8) Angina dataset
#
# This should be the third experiment

# %%
healthy_rad_samp4 = healthy_rad.sample(n=len(angina_rad))

# %%
angina_df = pd.concat([angina_rad, healthy_rad_samp4], axis=0)

# %%
angina_df.to_csv('Radiomics Experiment/angina_df.csv')

# %% [markdown]
# 9) Avoiding duplicates

# %%
ninth_exp = sixth_exp.drop_duplicates(subset='f.eid', keep=False)

# %%
ninth_exp['class'].value_counts()
# Out:
# healthy    777
# I251       374
# I48        205
# I209        95
# I200        51
# Name: class, dtype: int64

# %%
ninth_exp.to_csv('Radiomics Experiment/ninth_exp.csv')

# %% [markdown]
# 10) Strat w/ duplicates

# %%
tenth_exp = seventh_exp.drop_duplicates(subset='f.eid', keep=False)

# %%
tenth_exp['class'].value_counts()
# Out:
# healthy    777
# I251       374
# I48        205
# angina     146
# Name: class, dtype: int64

# %%
tenth_exp.to_csv('Radiomics Experiment/tenth_exp.csv')

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.index.droplevel(0)
    return df_

# %%
tenth_exp_ = stratified_sample_df(tenth_exp, 'class', 140)

# %%
tenth_exp_['class'].value_counts()
# Out:
# angina     140
# I48        140
# healthy    140
# I251       140
# Name: class, dtype: int64

# %%
tenth_exp_.to_csv('Radiomics Experiment/tenth_exp_strat.csv')

# %% [markdown]
# Multiclass only ATFB, ATH and ANGINA vs Healthy

# %%
MClass = pd.concat([I251_rad, I48_rad, angina_rad, healthy_rad], axis=0)

# %%
MClass = MClass.drop_duplicates(subset='f.eid', keep=False)

# %%
MClass['class'].value_counts()
# Out:
# HEALTHY    777
# ATH        374
# ATRFB      205
# ANGINA     146
# Name: class, dtype: int64

# %%
MC_class_strat = stratified_sample_df(MClass, 'class', 140)

# %%
MC_class_strat['class'].value_counts()
# Out:
# HEALTHY    140
# ATRFB      140
# ATH        140
# ANGINA     140
# Name: class, dtype: int64

# %%
MC_class_strat.to_csv('Radiomics Experiment/MC_class.csv')
