# %% [markdown]
# ## Fusion of Features UKBB

# %%
### import the packages and libraries

import pandas as pd
import matplotlib
#matplotlib.use('Qt5Agg')
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report, recall_score, precision_score, roc_auc_score, roc_curve
from sklearn.svm import LinearSVC, SVC
from sklearn.feature_selection import SelectKBest, f_classif, chi2, RFECV, RFE
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
import pickle
import seaborn as sns
from tabulate import tabulate

path1= r'C:\Users\alejandro\Documents\files_master\ATHEROSCLEROTIC\XL'
path2 = r'C:\Users\alejandro\Documents\files_master\Larger_Dataset\ATHEROSCLEROTIC'

# %% [markdown]
# ### Radiomics Features

# %%
HCR_raw = pd.read_csv(path2+ '/ATH_rad.csv', index_col=0)
print(HCR_raw.shape)


RF_df = HCR_raw.loc[:,~ HCR_raw.columns.str.startswith('diagnostics')]
print(RF_df.shape)
# Out:
# (1000, 680)
# (1000, 680)

# %%
RF_df.sort_values('f.eid', inplace=True)

# %%
y_train_df = RF_df['class']

rad_train = RF_df.iloc[:,:-1]

#ED_train_df = RF_df.filter(regex='ED')
#ES_train_df = RF_df.filter(regex='ES')

#rad_train = pd.concat([ED_train_df, ES_train_df], axis = 1)

# %%
rad_train.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 11   1003177   167950.4539        20927.86259                        0.125441
# 84   1023154   109174.4703        14942.90187                        0.138011
# 115  1033167   205265.3600        22463.36859                        0.110023
# 160  1043788   154633.2177        17678.57129                        0.114961
# 191  1052312   140047.6109        16370.91664                        0.117619
#
#      Sphericity_LV_ED SphericalDisproportion_LV_ED Compactness_LV_ED  \
# 11           0.700296                   Deprecated        Deprecated
# 84           0.735185                   Deprecated        Deprecated
# 115          0.746454                   Deprecated        Deprecated
# 160          0.785179                   Deprecated        Deprecated
# 191          0.793370                   Deprecated        Deprecated
#
#     Compactness2_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  ...  \
# 11          Deprecated            99.878718                 78.706257  ...
# 84          Deprecated            88.573143                 57.074903  ...
# 115         Deprecated           107.867732                 66.501006  ...
# 160         Deprecated           101.519383                 57.685655  ...
# 191         Deprecated            96.587382                 61.410804  ...
#
#      DependenceNonUniformityNormalized_gldm_MYO_ES  \
# 11                                        0.045827
# 84                                        0.056946
# 115                                       0.043090
# 160                                       0.046345
# 191                                       0.046755
#
#      GrayLevelVariance_gldm_MYO_ES  DependenceVariance_gldm_MYO_ES  \
# 11                        0.410879                       38.049748
# 84                        0.671856                       23.721865
# 115                       0.321625                       41.693987
# 160                       0.455542                       35.396728
# 191                       0.526792                       34.081403
#
#      DependenceEntropy_gldm_MYO_ES  LowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                        5.683738                          0.089275
# 84                        5.898869                          0.189246
# 115                       5.568289                          0.289766
# 160                       5.644355                          0.098938
# 191                       5.727677                          0.185505
#
#      HighGrayLevelEmphasis_gldm_MYO_ES  \
# 11                           13.459016
# 84                            8.144385
# 115                           4.883359
# 160                          11.971578
# 191                           7.216973
#
#      SmallDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                          0.004913
# 84                                          0.007164
# 115                                         0.016327
# 160                                         0.005307
# 191                                         0.009054
#
#      SmallDependenceHighGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                           0.506779
# 84                                           0.280300
# 115                                          0.186144
# 160                                          0.525834
# 191                                          0.394382
#
#      LargeDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                         15.885040
# 84                                         22.695810
# 115                                        50.957714
# 160                                        20.323454
# 191                                        36.416500
#
#      LargeDependenceHighGrayLevelEmphasis_gldm_MYO_ES
# 11                                        2807.541878
# 84                                        1106.657754
# 115                                        973.859513
# 160                                       2238.026672
# 191                                       1005.412625
#
# [5 rows x 679 columns]

# %%
count = 0
drop_list = list()
for col in rad_train.dtypes:
    if col == 'object':
        drop_list.append(count)
    count +=1

print(len(drop_list))


rad_train = rad_train.drop(rad_train.columns[drop_list], axis = 1)

rad_train.shape
# Out:
# 48
# (1000, 631)

# %%
rad_train.head()
# Out:
#        f.eid  Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 11   1003177   167950.4539        20927.86259                        0.125441
# 84   1023154   109174.4703        14942.90187                        0.138011
# 115  1033167   205265.3600        22463.36859                        0.110023
# 160  1043788   154633.2177        17678.57129                        0.114961
# 191  1052312   140047.6109        16370.91664                        0.117619
#
#      Sphericity_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  \
# 11           0.700296            99.878718                 78.706257
# 84           0.735185            88.573143                 57.074903
# 115          0.746454           107.867732                 66.501006
# 160          0.785179           101.519383                 57.685655
# 191          0.793370            96.587382                 61.410804
#
#      Max2DdiameterColumn_LV_ED  Max2DdiameterRow_LV_ED  MajorAxis_LV_ED  ...  \
# 11                   99.325807               99.325807        88.811055  ...
# 84                   86.495075               87.206026        74.793122  ...
# 115                 107.106969              102.374906        92.467324  ...
# 160                 100.925863              100.112362        94.164045  ...
# 191                  95.028975               93.102849        82.333115  ...
#
#      DependenceNonUniformityNormalized_gldm_MYO_ES  \
# 11                                        0.045827
# 84                                        0.056946
# 115                                       0.043090
# 160                                       0.046345
# 191                                       0.046755
#
#      GrayLevelVariance_gldm_MYO_ES  DependenceVariance_gldm_MYO_ES  \
# 11                        0.410879                       38.049748
# 84                        0.671856                       23.721865
# 115                       0.321625                       41.693987
# 160                       0.455542                       35.396728
# 191                       0.526792                       34.081403
#
#      DependenceEntropy_gldm_MYO_ES  LowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                        5.683738                          0.089275
# 84                        5.898869                          0.189246
# 115                       5.568289                          0.289766
# 160                       5.644355                          0.098938
# 191                       5.727677                          0.185505
#
#      HighGrayLevelEmphasis_gldm_MYO_ES  \
# 11                           13.459016
# 84                            8.144385
# 115                           4.883359
# 160                          11.971578
# 191                           7.216973
#
#      SmallDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                          0.004913
# 84                                          0.007164
# 115                                         0.016327
# 160                                         0.005307
# 191                                         0.009054
#
#      SmallDependenceHighGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                           0.506779
# 84                                           0.280300
# 115                                          0.186144
# 160                                          0.525834
# 191                                          0.394382
#
#      LargeDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 11                                         15.885040
# 84                                         22.695810
# 115                                        50.957714
# 160                                        20.323454
# 191                                        36.416500
#
#      LargeDependenceHighGrayLevelEmphasis_gldm_MYO_ES
# 11                                        2807.541878
# 84                                        1106.657754
# 115                                        973.859513
# 160                                       2238.026672
# 191                                       1005.412625
#
# [5 rows x 631 columns]

# %%
y_train_df.value_counts()
# Out:
# ATH        500
# HEALTHY    500
# Name: class, dtype: int64

# %%
rad_train.reset_index(inplace=True)

# %%
rad_train.head()
# Out:
#    index    f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 0     11  1003177   167950.4539        20927.86259
# 1     84  1023154   109174.4703        14942.90187
# 2    115  1033167   205265.3600        22463.36859
# 3    160  1043788   154633.2177        17678.57129
# 4    191  1052312   140047.6109        16370.91664
#
#    SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  Max3Ddiameter_LV_ED  \
# 0                        0.125441          0.700296            99.878718
# 1                        0.138011          0.735185            88.573143
# 2                        0.110023          0.746454           107.867732
# 3                        0.114961          0.785179           101.519383
# 4                        0.117619          0.793370            96.587382
#
#    Max2DdiameterSlice_LV_ED  Max2DdiameterColumn_LV_ED  \
# 0                 78.706257                  99.325807
# 1                 57.074903                  86.495075
# 2                 66.501006                 107.106969
# 3                 57.685655                 100.925863
# 4                 61.410804                  95.028975
#
#    Max2DdiameterRow_LV_ED  ...  DependenceNonUniformityNormalized_gldm_MYO_ES  \
# 0               99.325807  ...                                       0.045827
# 1               87.206026  ...                                       0.056946
# 2              102.374906  ...                                       0.043090
# 3              100.112362  ...                                       0.046345
# 4               93.102849  ...                                       0.046755
#
#    GrayLevelVariance_gldm_MYO_ES  DependenceVariance_gldm_MYO_ES  \
# 0                       0.410879                       38.049748
# 1                       0.671856                       23.721865
# 2                       0.321625                       41.693987
# 3                       0.455542                       35.396728
# 4                       0.526792                       34.081403
#
#    DependenceEntropy_gldm_MYO_ES  LowGrayLevelEmphasis_gldm_MYO_ES  \
# 0                       5.683738                          0.089275
# 1                       5.898869                          0.189246
# 2                       5.568289                          0.289766
# 3                       5.644355                          0.098938
# 4                       5.727677                          0.185505
#
#    HighGrayLevelEmphasis_gldm_MYO_ES  \
# 0                          13.459016
# 1                           8.144385
# 2                           4.883359
# 3                          11.971578
# 4                           7.216973
#
#    SmallDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 0                                         0.004913
# 1                                         0.007164
# 2                                         0.016327
# 3                                         0.005307
# 4                                         0.009054
#
#    SmallDependenceHighGrayLevelEmphasis_gldm_MYO_ES  \
# 0                                          0.506779
# 1                                          0.280300
# 2                                          0.186144
# 3                                          0.525834
# 4                                          0.394382
#
#    LargeDependenceLowGrayLevelEmphasis_gldm_MYO_ES  \
# 0                                        15.885040
# 1                                        22.695810
# 2                                        50.957714
# 3                                        20.323454
# 4                                        36.416500
#
#    LargeDependenceHighGrayLevelEmphasis_gldm_MYO_ES
# 0                                       2807.541878
# 1                                       1106.657754
# 2                                        973.859513
# 3                                       2238.026672
# 4                                       1005.412625
#
# [5 rows x 632 columns]

# %%
y_train_df.reset_index()
# Out:
#      index    class
# 0       11  HEALTHY
# 1       84  HEALTHY
# 2      115      ATH
# 3      160  HEALTHY
# 4      191  HEALTHY
# ..     ...      ...
# 995  19340  HEALTHY
# 996  19347      ATH
# 997  19371      ATH
# 998  19377  HEALTHY
# 999  19387      ATH
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### DLR

# %%
DLR_raw = pd.read_csv(path1+'/incep_features2.csv', index_col=0)

# %%
DLR_raw.head()
# Out:
#          0  ED_dlf_0  ED_dlf_1  ED_dlf_2  ED_dlf_3  ED_dlf_4  ED_dlf_5  \
# 0  5637964  0.264478  0.190815  0.349349  0.145674  0.313192  0.089170
# 1  1845338  0.409334  0.172861  0.480785  0.297732  0.086747  0.313169
# 2  2255798  0.254496  0.109666  0.430412  0.242189  0.214562  0.057885
# 3  5756803  0.555684  0.290650  0.351938  0.251363  0.116025  0.328087
# 4  4682100  0.000000  0.273713  0.000000  0.459242  0.523650  1.172591
#
#    ED_dlf_6  ED_dlf_7  ED_dlf_8  ...  ES_dlf_2038  ES_dlf_2039  ES_dlf_2040  \
# 0  0.000000  0.002517  0.122463  ...     0.031756     0.289142     0.021865
# 1  0.000000  0.004428  0.135187  ...     0.405597     0.198408     2.413202
# 2  0.000000  0.000493  0.087353  ...     1.165345     0.427254     2.970368
# 3  0.000000  0.000000  0.275005  ...     0.044537     0.950560     0.039800
# 4  0.223527  0.339254  0.088800  ...     0.000000     0.367542     1.352979
#
#    ES_dlf_2041  ES_dlf_2042  ES_dlf_2043  ES_dlf_2044  ES_dlf_2045  \
# 0     0.622178     0.057043     1.631585     0.139176     0.060746
# 1     0.035744     1.392584     2.656077     0.677844     0.060546
# 2     0.000000     2.768798     1.474746     0.484838     0.404661
# 3     0.079582     0.012288     0.235024     0.553732     0.000000
# 4     0.000000     1.036699     1.919991     0.262220     1.044607
#
#    ES_dlf_2046  ES_dlf_2047
# 0     0.000000     0.859001
# 1     0.000000     2.513367
# 2     0.000000     1.650134
# 3     0.181013     0.782815
# 4     0.003682     1.642962
#
# [5 rows x 4097 columns]

# %%
DLR_raw.sort_values('0', inplace=True)

# %%
DLR_raw.reset_index(inplace=True)

# %%
DLR_raw.shape
# Out:
# (998, 4098)

# %% [markdown]
# ### Concatenation

# %%
tot_set = pd.concat([rad_train, DLR_raw], axis=1)

# %%
count = 0
drop_list = list()
for col in tot_set.dtypes:
    if col == 'object':
        drop_list.append(count)
    count +=1

print(len(drop_list))
# Out:
# 0

# %% [markdown]
# The difference in shapes of the dataframes is because when getting the image, two patients weren't found in the database. The next lines are to detect which of those patients were not found and drop those.

# %%
tot_set.isna().sum()
# Out:
# index                             0
# f.eid                             0
# Volume_LV_ED                      0
# SurfaceArea_LV_ED                 0
# SurfaceAreatoVolumeRatio_LV_ED    0
#                                  ..
# ES_dlf_2043                       2
# ES_dlf_2044                       2
# ES_dlf_2045                       2
# ES_dlf_2046                       2
# ES_dlf_2047                       2
# Length: 4730, dtype: int64

# %%
indices = list(np.where(tot_set['ES_dlf_2047'].isna()))

# %%
tot_set.dropna(inplace=True)

# %%
tot_set.isna().sum().sum()
# Out:
# 0

# %%
tot_set.shape
# Out:
# (998, 4730)

# %%
tot_set.tail()
# Out:
#      index    f.eid  Volume_LV_ED  SurfaceArea_LV_ED  \
# 993  19310  6002379   164373.0823        19236.19841
# 994  19321  6004621   144304.7434        17361.49970
# 995  19340  6009243   151963.0995        18075.53927
# 996  19347  6010426   162186.7037        18265.41654
# 997  19371  6018226   125320.0000        15927.75707
#
#      SurfaceAreatoVolumeRatio_LV_ED  Sphericity_LV_ED  Max3Ddiameter_LV_ED  \
# 993                        0.117716          0.751426           110.458299
# 994                        0.121142          0.762826            99.410988
# 995                        0.119707          0.758648            92.282548
# 996                        0.113289          0.784299           101.562949
# 997                        0.128086          0.756422           100.199800
#
#      Max2DdiameterSlice_LV_ED  Max2DdiameterColumn_LV_ED  \
# 993                 67.575722                 104.736162
# 994                 57.852344                  97.873848
# 995                 63.075162                  90.363796
# 996                 64.824470                  97.203102
# 997                 63.245553                  96.932967
#
#      Max2DdiameterRow_LV_ED  ...  ES_dlf_2038  ES_dlf_2039  ES_dlf_2040  \
# 993              108.512306  ...     0.000000     0.914813     0.440892
# 994               97.134233  ...     0.000885     0.856715     0.004127
# 995               92.119649  ...     0.163221     0.276457     0.436056
# 996               98.728249  ...     0.195853     0.077899     3.045672
# 997               98.488578  ...     0.065678     0.873336     2.394707
#
#      ES_dlf_2041  ES_dlf_2042  ES_dlf_2043  ES_dlf_2044  ES_dlf_2045  \
# 993     0.000000     1.099374     0.158658     0.715127     0.610903
# 994     0.048077     0.110233     0.288661     0.048708     0.107434
# 995     0.000000     0.389977     0.875284     0.649409     0.000000
# 996     0.000000     1.596723     0.889014     2.469888     0.390226
# 997     0.000000     1.636230     0.361212     2.246362     0.359472
#
#      ES_dlf_2046  ES_dlf_2047
# 993     1.271303     1.826389
# 994     0.625053     0.015005
# 995     0.497262     1.045235
# 996     0.000000     1.872856
# 997     0.000000     1.055658
#
# [5 rows x 4730 columns]

# %%
y_train_df.tail()
# Out:
# 19340    HEALTHY
# 19347        ATH
# 19371        ATH
# 19377    HEALTHY
# 19387        ATH
# Name: class, dtype: object

# %%
y_train_df = y_train_df.iloc[:-2]

# %%
y_train_df.tail()
# Out:
# 19310        ATH
# 19321        ATH
# 19340    HEALTHY
# 19347        ATH
# 19371        ATH
# Name: class, dtype: object

# %% [markdown]
# We maintain the balance dataset

# %%
y_train_df.value_counts()
# Out:
# ATH        499
# HEALTHY    499
# Name: class, dtype: int64

# %%
ids = tot_set['f.eid']

# %%
tot_set.drop(['index', 'f.eid', '0'], axis=1, inplace=True)

# %%
tot_set.head()
# Out:
#    Volume_LV_ED  SurfaceArea_LV_ED  SurfaceAreatoVolumeRatio_LV_ED  \
# 0   167950.4539        20927.86259                        0.125441
# 1   109174.4703        14942.90187                        0.138011
# 2   205265.3600        22463.36859                        0.110023
# 3   154633.2177        17678.57129                        0.114961
# 4   140047.6109        16370.91664                        0.117619
#
#    Sphericity_LV_ED  Max3Ddiameter_LV_ED  Max2DdiameterSlice_LV_ED  \
# 0          0.700296            99.878718                 78.706257
# 1          0.735185            88.573143                 57.074903
# 2          0.746454           107.867732                 66.501006
# 3          0.785179           101.519383                 57.685655
# 4          0.793370            96.587382                 61.410804
#
#    Max2DdiameterColumn_LV_ED  Max2DdiameterRow_LV_ED  MajorAxis_LV_ED  \
# 0                  99.325807               99.325807        88.811055
# 1                  86.495075               87.206026        74.793122
# 2                 107.106969              102.374906        92.467324
# 3                 100.925863              100.112362        94.164045
# 4                  95.028975               93.102849        82.333115
#
#    MinorAxis_LV_ED  ...  ES_dlf_2038  ES_dlf_2039  ES_dlf_2040  ES_dlf_2041  \
# 0        60.156201  ...     0.090084     2.405276     0.362080     0.000000
# 1        48.066735  ...     0.379142     0.617370     0.000000     0.530999
# 2        57.957273  ...     0.148393     0.737299     1.964676     0.164535
# 3        50.749469  ...     0.000000     0.926969     2.171592     0.000000
# 4        50.883094  ...     0.000000     1.139364     0.042151     0.000000
#
#    ES_dlf_2042  ES_dlf_2043  ES_dlf_2044  ES_dlf_2045  ES_dlf_2046  \
# 0     1.724524     0.194541     1.550975     0.092816     0.614184
# 1     0.483395     0.090308     0.023641     0.068764     0.266425
# 2     0.827067     0.708553     0.766133     0.130027     0.000000
# 3     1.724887     1.810179     1.487633     1.927275     0.369022
# 4     0.985809     0.318012     0.313336     0.038570     1.096107
#
#    ES_dlf_2047
# 0     0.646367
# 1     0.240789
# 2     1.054853
# 3     2.405222
# 4     0.807331
#
# [5 rows x 4726 columns]

# %% [markdown]
# ### Y_class

# %%
class_list= list(y_train_df.unique())

# %% [markdown]
# ### ML Grid Search

# %%
def KBest_GS(X_train, y_train, X_test, y_test, model, param_grid, x_df):
    
    selector = SelectKBest()
    
    ### Pipeline
    
    ### we would need to adapt the "NUMBER OF FEATURES PARAMETER OF THE GRID"
    
    pipe = Pipeline([('selector', selector), 
                 ('model', model)])

    featss = np.array(range(5,1000+1))
    
    #featss = np.array(range(5,8))

    dict_1 = {'selector__score_func': [f_classif, chi2],
              'selector__k':featss}   #### para pruebas
    
    dict_1.update(param_grid)
    
    gs = GridSearchCV(estimator=pipe, 
                  param_grid=dict_1, 
                  scoring=['accuracy', 'roc_auc', 'f1', 'precision', 'recall'], 
                  n_jobs=1, 
                  cv=StratifiedKFold(3, shuffle=True, random_state=42),
                  refit='accuracy',
                verbose=1)
    
    print(pipe.get_params().keys())
    
    gs = gs.fit(X_train, y_train)
    
    print("Best Model", gs.best_params_)
    
    print('Best score:', gs.best_score_)
    
    y_test_pred = gs.predict(X_test)
    
    test_acc = accuracy_score(y_test,y_test_pred)
    probs=gs.predict_proba(X_test_p)
    probs = probs[:, 1]
    ROC_AUC = roc_auc_score(y_test, probs)
    precison_scor = precision_score(y_test,y_test_pred)
    recall_scor = recall_score(y_test, y_test_pred)
    
    fpr, tpr, thresholds = roc_curve(y_testp, probs)
    
    print("\n Test Accuracy with best estimator: ", test_acc)
    print("\n Roc AUC with best estimator: ", ROC_AUC)
    print("\n Precision with best estimator: ", precison_scor)
    print("\n Recall with best estimator: ", recall_scor, "\n")
    
    
    l = [[test_acc, ROC_AUC, precison_scor, recall_scor]]
    table = tabulate(l, headers=['Accuracy', 'ROC_AUC', 'Precision', 'Recall'], tablefmt='orgtbl')
    
    print(table)
    
    cm = confusion_matrix(y_test, y_test_pred)
        
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig = plt.figure(figsize=(10,4))
    fig.add_subplot(121)
#     plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    sns.heatmap(cm, annot=True, cmap=plt.cm.Blues, fmt='g')
    plt.tight_layout()

    tick_marks = np.arange(len(class_list))
    plt.xticks(tick_marks+0.5, class_list, rotation=45)
    plt.yticks(tick_marks+0.5, class_list)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    fig.add_subplot(122)
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.tight_layout()

    plt.show()

    print(classification_report(y_test, y_test_pred,target_names=class_list))
    
    cols = gs.best_estimator_.steps[0][1].get_support(indices=True)
    features_df_new = x_df.iloc[:,cols]
    K_best = list(features_df_new.columns)
    
    print(K_best)
    
    return gs, K_best

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
#Support Vector Classifier

model_SVC = SVC(gamma = 'scale', probability=True, max_iter= 5000, random_state=42)

param_grid_SVC =  {'model__kernel':('linear', 'rbf'), 
                   'model__C':[0.3, 0.5, 1,5, 10]}

# %%
scaler = MinMaxScaler()
X_sc = scaler.fit_transform(tot_set)

encoder = LabelEncoder()
y_enc = encoder.fit_transform(y_train_df)

# %%
X_train_p, X_test_p, y_trainp, y_testp = train_test_split(X_sc, y_enc, test_size=100,
                                                   shuffle=True,
                                                    stratify=y_train_df,
                                                   random_state=42)

# %%
gs, K_best = KBest_GS(X_train_p, y_trainp, X_test_p, y_testp, model_SVC, param_grid_SVC, tot_set)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'selector', 'model', 'selector__k', 'selector__score_func', 'model__C', 'model__break_ties', 'model__cache_size', 'model__class_weight', 'model__coef0', 'model__decision_function_shape', 'model__degree', 'model__gamma', 'model__kernel', 'model__max_iter', 'model__probability', 'model__random_state', 'model__shrinking', 'model__tol', 'model__verbose'])
# Fitting 3 folds for each of 19920 candidates, totalling 59760 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# ...
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\alejandro\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [Parallel(n_jobs=1)]: Done 59760 out of 59760 | elapsed: 754.8min finished
# Best Model {'model__C': 0.3, 'model__kernel': 'linear', 'selector__k': 183, 'selector__score_func': <function f_classif at 0x0000021775492EE0>}
# Best score: 0.785061315496098
#
#  Test Accuracy with best estimator:  0.79
#
#  Roc AUC with best estimator:  0.8220000000000001
#
#  Precision with best estimator:  0.8085106382978723
#
#  Recall with best estimator:  0.76
#
# |   Accuracy |   ROC_AUC |   Precision |   Recall |
# |------------+-----------+-------------+----------|
# |       0.79 |     0.822 |    0.808511 |     0.76 |
#               precision    recall  f1-score   support
#
#      HEALTHY       0.77      0.82      0.80        50
#          ATH       0.81      0.76      0.78        50
#
#     accuracy                           0.79       100
#    macro avg       0.79      0.79      0.79       100
# weighted avg       0.79      0.79      0.79       100
#
# ['Volume_MYO_ED', 'SurfaceAreatoVolumeRatio_MYO_ED', 'Sphericity_MYO_ED', 'Volume_MYO_ES', 'SurfaceAreatoVolumeRatio_MYO_ES', 'Percentile10_LV_ED', 'Percentile90_LV_ED', 'Mean_LV_ED', 'Median_LV_ED', 'RootMeanSquared_LV_ED', 'Skewness_LV_ED', 'Kurtosis_LV_ED', 'Entropy_LV_ES', 'Percentile10_LV_ES', 'Percentile90_LV_ES', 'Maximum_LV_ES', 'Mean_LV_ES', 'Median_LV_ES', 'InterquartileRange_LV_ES', 'MeanAbsoluteDeviation_LV_ES', 'RobustMeanAbsoluteDeviation_LV_ES', 'RootMeanSquared_LV_ES', 'Variance_LV_ES', 'Percentile10_RV_ED', 'Percentile90_RV_ED', 'Mean_RV_ED', 'Median_RV_ED', 'RootMeanSquared_RV_ED', 'Skewness_RV_ED', 'Entropy_RV_ES', 'Percentile10_RV_ES', 'Percentile90_RV_ES', 'Mean_RV_ES', 'Median_RV_ES', 'InterquartileRange_RV_ES', 'MeanAbsoluteDeviation_RV_ES', 'RobustMeanAbsoluteDeviation_RV_ES', 'RootMeanSquared_RV_ES', 'Entropy_MYO_ED', 'Percentile90_MYO_ED', 'InterquartileRange_MYO_ED', 'MeanAbsoluteDeviation_MYO_ED', 'RobustMeanAbsoluteDeviation_MYO_ED', 'Variance_MYO_ED', 'Uniformity_MYO_ED', 'Percentile90_MYO_ES', 'Mean_MYO_ES', 'Median_MYO_ES', 'RootMeanSquared_MYO_ES', 'Autocorrelation_glcm_LV_ED', 'JointAverage_glcm_LV_ED', 'ClusterShade_glcm_LV_ED', 'SumAverage_glcm_LV_ED', 'Autocorrelation_glcm_LV_ES', 'JointAverage_glcm_LV_ES', 'ClusterTendency_glcm_LV_ES', 'SumAverage_glcm_LV_ES', 'SumEntropy_glcm_LV_ES', 'SumofSquares_glcm_LV_ES', 'Autocorrelation_glcm_RV_ED', 'JointAverage_glcm_RV_ED', 'SumAverage_glcm_RV_ED', 'Autocorrelation_glcm_RV_ES', 'JointAverage_glcm_RV_ES', 'DifferenceEntropy_glcm_RV_ES', 'DifferenceVariance_glcm_RV_ES', 'InverseVariance_glcm_RV_ES', 'SumAverage_glcm_RV_ES', 'JointAverage_glcm_MYO_ED', 'ClusterTendency_glcm_MYO_ED', 'Contrast_glcm_MYO_ED', 'DifferenceAverage_glcm_MYO_ED', 'DifferenceEntropy_glcm_MYO_ED', 'DifferenceVariance_glcm_MYO_ED', 'JointEntropy_glcm_MYO_ED', 'InverseDifferenceMoment_glcm_MYO_ED', 'InverseDifference_glcm_MYO_ED', 'SumAverage_glcm_MYO_ED', 'SumEntropy_glcm_MYO_ED', 'SumofSquares_glcm_MYO_ED', 'Autocorrelation_glcm_MYO_ES', 'JointAverage_glcm_MYO_ES', 'SumAverage_glcm_MYO_ES', 'GrayLevelNonUniformityNormalized_glszm_LV_ED', 'ZonePercentage_glszm_LV_ED', 'LargeAreaLowGrayLevelEmphasis_glszm_LV_ED', 'ZonePercentage_glszm_LV_ES', 'GrayLevelNonUniformity_glszm_RV_ED', 'SizeZoneNonUniformity_glszm_RV_ED', 'ZonePercentage_glszm_RV_ED', 'ZonePercentage_glszm_RV_ES', 'LargeAreaEmphasis_glszm_MYO_ED', 'GrayLevelNonUniformityNormalized_glszm_MYO_ED', 'ZonePercentage_glszm_MYO_ED', 'ZoneVariance_glszm_MYO_ED', 'LargeAreaLowGrayLevelEmphasis_glszm_MYO_ED', 'LargeAreaEmphasis_glszm_MYO_ES', 'GrayLevelNonUniformityNormalized_glszm_MYO_ES', 'ZoneVariance_glszm_MYO_ES', 'LargeAreaLowGrayLevelEmphasis_glszm_MYO_ES', 'LowGrayLevelRunEmphasis_glrlm_LV_ED', 'HighGrayLevelRunEmphasis_glrlm_LV_ED', 'ShortRunLowGrayLevelEmphasis_glrlm_LV_ED', 'ShortRunHighGrayLevelEmphasis_glrlm_LV_ED', 'LongRunLowGrayLevelEmphasis_glrlm_LV_ED', 'LongRunHighGrayLevelEmphasis_glrlm_LV_ED', 'GrayLevelNonUniformityNormalized_glrlm_LV_ES', 'GrayLevelVariance_glrlm_LV_ES', 'HighGrayLevelRunEmphasis_glrlm_LV_ES', 'ShortRunHighGrayLevelEmphasis_glrlm_LV_ES', 'LongRunHighGrayLevelEmphasis_glrlm_LV_ES', 'LowGrayLevelRunEmphasis_glrlm_RV_ED', 'HighGrayLevelRunEmphasis_glrlm_RV_ED', 'ShortRunLowGrayLevelEmphasis_glrlm_RV_ED', 'ShortRunHighGrayLevelEmphasis_glrlm_RV_ED', 'LongRunLowGrayLevelEmphasis_glrlm_RV_ED', 'LongRunHighGrayLevelEmphasis_glrlm_RV_ED', 'GrayLevelNonUniformityNormalized_glrlm_RV_ES', 'HighGrayLevelRunEmphasis_glrlm_RV_ES', 'ShortRunHighGrayLevelEmphasis_glrlm_RV_ES', 'ShortRunEmphasis_glrlm_MYO_ED', 'LongRunEmphasis_glrlm_MYO_ED', 'GrayLevelNonUniformity_glrlm_MYO_ED', 'GrayLevelNonUniformityNormalized_glrlm_MYO_ED', 'RunLengthNonUniformityNormalized_glrlm_MYO_ED', 'RunPercentage_glrlm_MYO_ED', 'GrayLevelVariance_glrlm_MYO_ED', 'RunVariance_glrlm_MYO_ED', 'HighGrayLevelRunEmphasis_glrlm_MYO_ED', 'ShortRunHighGrayLevelEmphasis_glrlm_MYO_ED', 'LongRunLowGrayLevelEmphasis_glrlm_MYO_ED', 'GrayLeve ...

# %%
top15 = pd.Series(abs(gs.best_estimator_.named_steps.model.coef_[0]), index=K_best).nlargest(15)


# In[107]:


top15.sort_values(ascending = True, inplace=True)

# %%
plt.figure(figsize=(12,6))
top15.plot(kind='barh', title='Top 15 Features Selected')
plt.ylabel('Feature name')
plt.xlabel('Coefficient')
plt.show()
